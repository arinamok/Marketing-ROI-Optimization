# %% [markdown]
# #**Marketing A/B Test Analysis**
# #### **Goal:** Compare Ad vs PSA performance, calculate lift, and analyze exposure/time effects

# %%
# Import libraries
import pandas as pd
import numpy as np
from statsmodels.stats.proportion import proportions_ztest, confint_proportions_2indep

# %% [markdown]
# #### **1. Dataset Initalization**

# %%
# Loading the AB_test_campaign_data.csv exported from the SQL database.
df = pd.read_csv("AB_test_campaign_data.csv")

# %%
# Check of data structure
print("First 5 rows:\n", df.head())
print("\nTest group counts:\n", df['test_group'].value_counts())
print("\nConversion counts (0/1):\n", df['converted'].value_counts())
# Out:
# First 5 rows:
#     user_id test_group  converted  total_ads  most_ads_hour
# 0  1164786         ad          0         18             11
# 1  1390129         ad          0         89              6
# 2  1041549         ad          0         45             10
# 3  1230477         ad          0          7             11
# 4  1381797         ad          0         15             22
#
# Test group counts:
#  test_group
# ad     33568
# psa     1432
# Name: count, dtype: int64
#
# Conversion counts (0/1):
#  converted
# 0    34131
# 1      869
# Name: count, dtype: int64

# %% [markdown]
# #### **2. Conversion Metrics & Lift**

# %%
# Calculate the conversion rates for both the 'Ad' and 'PSA' groups to determine the overall percentage lift.
# Group byprint(f"\nConversion Rate (Ad): {ad_conv:.4f}")
conversion_summary = df.groupby('test_group')['converted'].agg(['sum','count'])
conversion_summary['conversion_rate'] = conversion_summary['sum'] / conversion_summary['count']

# %%
ad_conv = conversion_summary.loc['ad', 'conversion_rate']
psa_conv = conversion_summary.loc['psa', 'conversion_rate']

# %%
print(f"\nConversion Rate (Ad): {ad_conv:.4f}")
print(f"Conversion Rate (PSA): {psa_conv:.4f}")
# Out:
# Conversion Rate (Ad): 0.0251
# Conversion Rate (PSA): 0.0196

# %%
# Calculate overall lift
# Lift % = how much better ad is compared to PSA
lift = (ad_conv - psa_conv) / psa_conv * 100
print(f"Overall Lift: {lift:.2f}%")
# Out:
# Overall Lift: 28.13%

# %% [markdown]
# #### **3. Statistical Significance Testing**

# %%
# Perform a two-proportion z-test and calculate the 95% confidence interval to determine if the difference
# in conversion rates is statistically significant ($p < 0.05$) or likely due to random chance.
count = np.array([conversion_summary.loc['ad','sum'], conversion_summary.loc['psa','sum']])
nobs = np.array([conversion_summary.loc['ad','count'], conversion_summary.loc['psa','count']])
stat, pval = proportions_ztest(count, nobs)
print(f"Z-test p-value: {pval:.4f}")
# Out:
# Z-test p-value: 0.1902

# %%
# 95% Confidence Interval for difference in conversion rates
ci_low, ci_upp = confint_proportions_2indep(count1=count[0], nobs1=nobs[0],
                                            count2=count[1], nobs2=nobs[1],
                                            method='agresti-caffo')
print(f"95% CI for difference: ({ci_low:.4f}, {ci_upp:.4f})")
# Out:
# 95% CI for difference: (-0.0026, 0.0123)

# %%
# Interpretation
if pval < 0.05:
  print("\nResult: Statistically significant difference between Ad and PSA.")
else:
  print("\nResult: No statistically significant difference between Ad and PSA.")
  print(f"Ad has a {lift:.2f}% lift over PSA.")
# Out:
# Result: No statistically significant difference between Ad and PSA.
# Ad has a 28.13% lift over PSA.

# %% [markdown]
# #### **4. Segmented Analysis: Lift by Exposure**

# %%
# Analyze how the number of ads seen (total_ads) impacts the effectiveness of the campaign using bucketed exposure levels.
# Categorize total_ads into buckets
df['ads_bucket'] = pd.cut(df['total_ads'],
                          bins=[-1, 50, 200, np.inf],
                          labels=['0-50', '51-200', '200+'])

# %%
# Group by ads_bucket and test_group, calculate conversion rates and lift
exposure_summary = df.groupby(['ads_bucket','test_group'])['converted'].agg(['sum','count']).reset_index()
exposure_pivot = exposure_summary.pivot(index='ads_bucket', columns='test_group', values=['sum','count'])
exposure_pivot.columns = ['_'.join(col).strip() for col in exposure_pivot.columns.values]
# Out:
# /tmp/ipython-input-2805218315.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   exposure_summary = df.groupby(['ads_bucket','test_group'])['converted'].agg(['sum','count']).reset_index()

# %%
# Calculate conversion rates and lift per bucket
exposure_pivot['ad_rate'] = exposure_pivot['sum_ad'] / exposure_pivot['count_ad']
exposure_pivot['psa_rate'] = exposure_pivot['sum_psa'] / exposure_pivot['count_psa']
exposure_pivot['lift_pct'] = (exposure_pivot['ad_rate'] - exposure_pivot['psa_rate']) / exposure_pivot['psa_rate'] * 100

# %%
# Format the columns for better readability
analysis_output = exposure_pivot[['ad_rate', 'psa_rate', 'lift_pct']].reset_index()

# Make the numbers look like percentages/neat decimals
final_table = analysis_output.style.format({
    'ad_rate': '{:.4f}',
    'psa_rate': '{:.4f}',
    'lift_pct': '{:.4f}%'
}).hide(axis="index").set_properties(**{'text-align': 'center'})

# Print table
final_table
# Out:
# <style type="text/css">
# #T_4f3b5_row0_col0, #T_4f3b5_row0_col1, #T_4f3b5_row0_col2, #T_4f3b5_row0_col3, #T_4f3b5_row1_col0, #T_4f3b5_row1_col1, #T_4f3b5_row1_col2, #T_4f3b5_row1_col3, #T_4f3b5_row2_col0, #T_4f3b5_row2_col1, #T_4f3b5_row2_col2, #T_4f3b5_row2_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_4f3b5" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_4f3b5_level0_col0" class="col_heading level0 col0" >ads_bucket</th>
#       <th id="T_4f3b5_level0_col1" class="col_heading level0 col1" >ad_rate</th>
#       <th id="T_4f3b5_level0_col2" class="col_heading level0 col2" >psa_rate</th>
#       <th id="T_4f3b5_level0_col3" class="col_heading level0 col3" >lift_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4f3b5_row0_col0" class="data row0 col0" >0-50</td>
#       <td id="T_4f3b5_row0_col1" class="data row0 col1" >0.0112</td>
#       <td id="T_4f3b5_row0_col2" class="data row0 col2" >0.0111</td>
#       <td id="T_4f3b5_row0_col3" class="data row0 col3" >0.5146%</td>
#     </tr>
#     <tr>
#       <td id="T_4f3b5_row1_col0" class="data row1 col0" >51-200</td>
#       <td id="T_4f3b5_row1_col1" class="data row1 col1" >0.1274</td>
#       <td id="T_4f3b5_row1_col2" class="data row1 col2" >0.0850</td>
#       <td id="T_4f3b5_row1_col3" class="data row1 col3" >49.9772%</td>
#     </tr>
#     <tr>
#       <td id="T_4f3b5_row2_col0" class="data row2 col0" >200+</td>
#       <td id="T_4f3b5_row2_col1" class="data row2 col1" >0.1611</td>
#       <td id="T_4f3b5_row2_col2" class="data row2 col2" >0.0556</td>
#       <td id="T_4f3b5_row2_col3" class="data row2 col3" >190.0000%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **5. Temporal Analysis: Lift by Peak Hour**

# %%
# Lift by Hour (most_ads_hour)
# Group by most_ads_hour and test_group
hour_summary = df.groupby(['most_ads_hour','test_group'])['converted'].agg(['sum','count']).reset_index()
hour_pivot = hour_summary.pivot(index='most_ads_hour', columns='test_group', values=['sum','count'])
hour_pivot.columns = ['_'.join(col).strip() for col in hour_pivot.columns.values]

# %%
# Calculate conversion rates and lift per hour
hour_pivot['ad_rate'] = hour_pivot['sum_ad'] / hour_pivot['count_ad']
hour_pivot['psa_rate'] = hour_pivot['sum_psa'] / hour_pivot['count_psa']
hour_pivot['lift_pct'] = (hour_pivot['ad_rate'] - hour_pivot['psa_rate']) / hour_pivot['psa_rate'] * 100

# %%
# Select the data
hour_display = hour_pivot[['ad_rate', 'psa_rate', 'lift_pct']].reset_index()

# Level all headers, apply 4-decimal formatting, and center data for a clean report layout
styled_table = hour_display.style.format({
    'ad_rate': '{:.4f}',
    'psa_rate': '{:.4f}',
    'lift_pct': '{:.4f}%'
}).hide(axis="index").set_properties(**{'text-align': 'center'})

# Print table
styled_table
# Out:
# <style type="text/css">
# #T_cedae_row0_col0, #T_cedae_row0_col1, #T_cedae_row0_col2, #T_cedae_row0_col3, #T_cedae_row1_col0, #T_cedae_row1_col1, #T_cedae_row1_col2, #T_cedae_row1_col3, #T_cedae_row2_col0, #T_cedae_row2_col1, #T_cedae_row2_col2, #T_cedae_row2_col3, #T_cedae_row3_col0, #T_cedae_row3_col1, #T_cedae_row3_col2, #T_cedae_row3_col3, #T_cedae_row4_col0, #T_cedae_row4_col1, #T_cedae_row4_col2, #T_cedae_row4_col3, #T_cedae_row5_col0, #T_cedae_row5_col1, #T_cedae_row5_col2, #T_cedae_row5_col3, #T_cedae_row6_col0, #T_cedae_row6_col1, #T_cedae_row6_col2, #T_cedae_row6_col3, #T_cedae_row7_col0, #T_cedae_row7_col1, #T_cedae_row7_col2, #T_cedae_row7_col3, #T_cedae_row8_col0, #T_cedae_row8_col1, #T_cedae_row8_col2, #T_cedae_row8_col3, #T_cedae_row9_col0, #T_cedae_row9_col1, #T_cedae_row9_col2, #T_cedae_row9_col3, #T_cedae_row10_col0, #T_cedae_row10_col1, #T_cedae_row10_col2, #T_cedae_row10_col3, #T_cedae_row11_col0, #T_cedae_row11_col1, #T_cedae_row11_col2, #T_cedae_row11_col3, #T_cedae_row12_col0, #T_cedae_row12_col1, #T_cedae_row12_col2, #T_cedae_row12_col3, #T_cedae_row13_col0, #T_cedae_row13_col1, #T_cedae_row13_col2, #T_cedae_row13_col3, #T_cedae_row14_col0, #T_cedae_row14_col1, #T_cedae_row14_col2, #T_cedae_row14_col3, #T_cedae_row15_col0, #T_cedae_row15_col1, #T_cedae_row15_col2, #T_cedae_row15_col3, #T_cedae_row16_col0, #T_cedae_row16_col1, #T_cedae_row16_col2, #T_cedae_row16_col3, #T_cedae_row17_col0, #T_cedae_row17_col1, #T_cedae_row17_col2, #T_cedae_row17_col3, #T_cedae_row18_col0, #T_cedae_row18_col1, #T_cedae_row18_col2, #T_cedae_row18_col3, #T_cedae_row19_col0, #T_cedae_row19_col1, #T_cedae_row19_col2, #T_cedae_row19_col3, #T_cedae_row20_col0, #T_cedae_row20_col1, #T_cedae_row20_col2, #T_cedae_row20_col3, #T_cedae_row21_col0, #T_cedae_row21_col1, #T_cedae_row21_col2, #T_cedae_row21_col3, #T_cedae_row22_col0, #T_cedae_row22_col1, #T_cedae_row22_col2, #T_cedae_row22_col3, #T_cedae_row23_col0, #T_cedae_row23_col1, #T_cedae_row23_col2, #T_cedae_row23_col3 {
#   text-align: center;
# }
# </style>
# <table id="T_cedae" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_cedae_level0_col0" class="col_heading level0 col0" >most_ads_hour</th>
#       <th id="T_cedae_level0_col1" class="col_heading level0 col1" >ad_rate</th>
#       <th id="T_cedae_level0_col2" class="col_heading level0 col2" >psa_rate</th>
#       <th id="T_cedae_level0_col3" class="col_heading level0 col3" >lift_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cedae_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_cedae_row0_col1" class="data row0 col1" >0.0098</td>
#       <td id="T_cedae_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_cedae_row0_col3" class="data row0 col3" >inf%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_cedae_row1_col1" class="data row1 col1" >0.0217</td>
#       <td id="T_cedae_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_cedae_row1_col3" class="data row1 col3" >inf%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_cedae_row2_col1" class="data row2 col1" >0.0126</td>
#       <td id="T_cedae_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_cedae_row2_col3" class="data row2 col3" >inf%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_cedae_row3_col1" class="data row3 col1" >0.0195</td>
#       <td id="T_cedae_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_cedae_row3_col3" class="data row3 col3" >inf%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_cedae_row4_col1" class="data row4 col1" >0.0000</td>
#       <td id="T_cedae_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_cedae_row4_col3" class="data row4 col3" >nan%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_cedae_row5_col1" class="data row5 col1" >0.0270</td>
#       <td id="T_cedae_row5_col2" class="data row5 col2" >nan</td>
#       <td id="T_cedae_row5_col3" class="data row5 col3" >nan%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_cedae_row6_col1" class="data row6 col1" >0.0308</td>
#       <td id="T_cedae_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_cedae_row6_col3" class="data row6 col3" >inf%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_cedae_row7_col1" class="data row7 col1" >0.0139</td>
#       <td id="T_cedae_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_cedae_row7_col3" class="data row7 col3" >inf%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_cedae_row8_col1" class="data row8 col1" >0.0224</td>
#       <td id="T_cedae_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_cedae_row8_col3" class="data row8 col3" >inf%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_cedae_row9_col1" class="data row9 col1" >0.0191</td>
#       <td id="T_cedae_row9_col2" class="data row9 col2" >0.0286</td>
#       <td id="T_cedae_row9_col3" class="data row9 col3" >-33.3141%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_cedae_row10_col1" class="data row10 col1" >0.0226</td>
#       <td id="T_cedae_row10_col2" class="data row10 col2" >0.0143</td>
#       <td id="T_cedae_row10_col3" class="data row10 col3" >57.9917%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_cedae_row11_col1" class="data row11 col1" >0.0267</td>
#       <td id="T_cedae_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_cedae_row11_col3" class="data row11 col3" >inf%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_cedae_row12_col1" class="data row12 col1" >0.0186</td>
#       <td id="T_cedae_row12_col2" class="data row12 col2" >0.0233</td>
#       <td id="T_cedae_row12_col3" class="data row12 col3" >-19.8359%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row13_col0" class="data row13 col0" >13</td>
#       <td id="T_cedae_row13_col1" class="data row13 col1" >0.0252</td>
#       <td id="T_cedae_row13_col2" class="data row13 col2" >0.0200</td>
#       <td id="T_cedae_row13_col3" class="data row13 col3" >26.1887%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row14_col0" class="data row14 col0" >14</td>
#       <td id="T_cedae_row14_col1" class="data row14 col1" >0.0317</td>
#       <td id="T_cedae_row14_col2" class="data row14 col2" >0.0190</td>
#       <td id="T_cedae_row14_col3" class="data row14 col3" >66.6348%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row15_col0" class="data row15 col0" >15</td>
#       <td id="T_cedae_row15_col1" class="data row15 col1" >0.0270</td>
#       <td id="T_cedae_row15_col2" class="data row15 col2" >0.0442</td>
#       <td id="T_cedae_row15_col3" class="data row15 col3" >-38.9917%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row16_col0" class="data row16 col0" >16</td>
#       <td id="T_cedae_row16_col1" class="data row16 col1" >0.0310</td>
#       <td id="T_cedae_row16_col2" class="data row16 col2" >0.0412</td>
#       <td id="T_cedae_row16_col3" class="data row16 col3" >-24.8239%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row17_col0" class="data row17 col0" >17</td>
#       <td id="T_cedae_row17_col1" class="data row17 col1" >0.0262</td>
#       <td id="T_cedae_row17_col2" class="data row17 col2" >0.0097</td>
#       <td id="T_cedae_row17_col3" class="data row17 col3" >169.9383%</td>
#     </tr>
#     <tr>
#       <td id="T_cedae_row18_col0" class="data row18 col0" >18</td>
#       <td id="T_cedae_row18_col1" class="data row18 col1" >0.0265</td>
#       <td id="T_cedae_row18_col2" class="data row18 col2" >0.0361</td>
#       <td id="T_cedae_row18_col3" cla
